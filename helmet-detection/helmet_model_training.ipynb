# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="k5LvHek09pAXOx7Dn5d3")
project = rf.workspace("bike-helmets").project("bike-helmet-detection-2vdjo")
dataset = project.version(2).download("yolov5")
# Out:
# ...
#   Using cached roboflow-1.1.7-py3-none-any.whl (58 kB)
# ...
#   Using cached certifi-2022.12.7-py3-none-any.whl (155 kB)
# ...
#   Using cached chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# ...
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# ...
#   Using cached opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
# ...
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# ...
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# ...
#   Using cached supervision-0.16.0-py3-none-any.whl (72 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16026, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 16026 (delta 33), reused 41 (delta 25), pack-reused 15967
# Receiving objects: 100% (16026/16026), 14.61 MiB | 21.65 MiB/s, done.
# Resolving deltas: 100% (10999/10999), done.

# %%
# !pip install -r /content/yolov5/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 27.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.2 MB/s eta 0:00:00
# ...

# %%
# !python3 /content/yolov5/train.py --img 640 --batch 8 --epochs 50 --data /content/data.yaml --weights yolov5s.pt --cache
# Out:
# 2023-10-28 11:12:47.307253: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-28 11:12:47.307334: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-28 11:12:47.307380: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !mv /content/yolov5/runs/train/exp3 /content/drive/MyDrive/wobot/helmet_detection/
